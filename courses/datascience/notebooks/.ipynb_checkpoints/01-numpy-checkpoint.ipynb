# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])
arr
# Out:
# array([1, 2, 3, 4])

# %%
a = [1, 2, 3]
b = [4, 5, 6]

result = []

for i in range(len(a)):
    result.append(a[i] + b[i])

print(result)
# Out:
# [5, 7, 9]
